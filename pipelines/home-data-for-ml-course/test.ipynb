# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("working/submission.csv")

# %%
df2 = pd.read_csv("working/submission_skrub.csv")
df3 = pd.read_csv("working/submission_skrub_gemini.csv")

# %%
delta = np.abs(df2["SalePrice"] - df["SalePrice"])

# %%
delta2 = np.abs(df3["SalePrice"] - df["SalePrice"])

# %%
delta.mean(), delta2.mean()
# Out:
# (np.float64(48.00630204200758), np.float64(48.00630204200758))

# %%
delta.max()
# Out:
# np.float64(33548.12527741777)
